# %%
# !pip install openai
# !pip install pymupdf
# !pip install pdf2image
# !pip install pillow
# !pip install pytesseract
# !pip install google-generativeai
# Out:
# Requirement already satisfied: openai in c:\users\vaish\anaconda3\lib\site-packages (2.41.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in c:\users\vaish\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\vaish\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\vaish\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\vaish\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\vaish\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\vaish\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\vaish\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\vaish\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: colorama in c:\users\vaish\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: pymupdf in c:\users\vaish\anaconda3\lib\site-packages (1.27.2.3)
# Requirement already satisfied: pdf2image in c:\users\vaish\anaconda3\lib\site-packages (1.17.0)
# Requirement already satisfied: pillow in c:\users\vaish\anaconda3\lib\site-packages (from pdf2image) (11.3.0)
# Requirement already satisfied: pillow in c:\users\vaish\anaconda3\lib\site-packages (11.3.0)
# Requirement already satisfied: pytesseract in c:\users\vaish\anaconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\vaish\anaconda3\lib\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from pytesseract) (11.3.0)
# Requirement already satisfied: google-generativeai in c:\users\vaish\anaconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (2.5.3)
# Requirement already satisfied: tqdm in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\vaish\anaconda3\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\vaish\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vaish\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vaish\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\vaish\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\vaish\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.14.6)
# Requirement already satisfied: colorama in c:\users\vaish\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\vaish\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\vaish\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\vaish\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vaish\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.10.5)

# %%
import fitz
import pytesseract
import os

from PIL import Image
from pdf2image import convert_from_path

import google.generativeai as genai

# %%
genai.configure(
    api_key="AQ.Ab8RN6L9Y9P1e0l_bw8uaiDpQHK2hCZcNvAXMmcSUFx1jqIuIA"
)

model = genai.GenerativeModel(
    "gemini-2.5-flash"
)

print("Gemini Connected Successfully")
# Out:
# Gemini Connected Successfully

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

print("OCR Ready")
# Out:
# OCR Ready

# %%
from tkinter import Tk
from tkinter.filedialog import askopenfilename

Tk().withdraw()

pdf_path = askopenfilename(
    title="Select Patient PDF"
)

print(pdf_path)
# Out:
# C:/Users/vaish/Downloads/patient 2 (1).pdf

# %%
from pdf2image import convert_from_path

pages = convert_from_path(
    pdf_path,
    poppler_path=r"C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\bin"
)

print("Pages:", len(pages))

# %%
import os

path = r"C:\Users\vaish\Downloads\Release-24.08.0-0"

for root, dirs, files in os.walk(path):
    print(root)
# Out:
# C:\Users\vaish\Downloads\Release-24.08.0-0
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\bin
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include\poppler
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include\poppler\cpp
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include\poppler\fofi
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include\poppler\glib
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include\poppler\goo
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\include\poppler\splash
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\lib
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\lib\pkgconfig
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\share
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\share\man
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\share\man\man1
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cidToUnicode
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap\Adobe-CNS1
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap\Adobe-GB1
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap\Adobe-Japan1
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap\Adobe-Japan2
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap\Adobe-Korea1
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\cMap\Adobe-KR
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\nameToUnicode
# C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\share\poppler\unicodeMap

# %%
from pdf2image import convert_from_path

pages = convert_from_path(
    pdf_path,
    poppler_path=r"C:\Users\vaish\Downloads\Release-24.08.0-0\poppler-24.08.0\Library\bin",
    first_page=1,
    last_page=5
)

print("Pages:", len(pages))
# Out:
# Pages: 5

# %%
import pytesseract

all_text = ""

for i, page in enumerate(pages):

    text = pytesseract.image_to_string(page)

    all_text += text

    print(f"Page {i+1} Processed")

print("\nOCR Completed")
# Out:
# Page 1 Processed
# Page 2 Processed
# Page 3 Processed
# Page 4 Processed
# Page 5 Processed
#
# OCR Completed

# %%
print(all_text[:5000])
# Out:
# DIAGNOSIS:
#
# 1) ACUTE GASTROENTERITIS WITH DEHYDRATION
# 2) URINARY TRACT INFECTION
#
# HISTORY: C/O Multiple episodes of loose stools, 2-3 episodes of vomiting,
# fatigue since 3 days and fever since yesterday.
# Initially she was treated at local clinic.
#
# PAST HISTOR Y:K/C/O Thyroid disorder on treatment,
#
# PHYSICAL EXAMINATION:
#
# PR-89/min, BP-130/80 mmHg, RR-20/min, SPO2-98"5 at room air.
# CNS-Conscious Oriented
#
# CVS-5152(+)
#
# RS-B/L NVBS(+)
#
# PA-Soft, non tender
#
# INVESTIGATIONS:
#
# Reports Enclosed
#
# COURSE IN THE HOSPITAL:
#
# Patient presented to us with above mentioned complaints. After evaluation, she
# was admitted to ward. Initial investigations showed normal CBC. Serum
# creatinine (1.65me/dl) done was elevated. Serum electrolytes done showed low
# serum sodium(125.00mnol/L). Urine routine done showed ketone bodies(+), 10-
# I2/hpf of pus cells, 13-20/hpf of epithelial cells with presence of bactreia hence
# urine culture and sensitivity sent- report awaited, She was treated with IV fluids,
# IV antibiotics, 1V PPI's, [V antiemetics and other supportive measures. USG
# abdomen and pelvis done showed Grade-I fatty liver changes and mildly
# edematous part of ascending colon upto the hepatic flexure- could represent
# colitis. Repeat Serum Creatinine(|.]7?meg/dl) done was normal. TSH and Free
# T4 done were normal. Stool routine done showed 2-3/hpf of red blood cells,
# plenty/hpf of pus cells. Patient was adviced to stay back for further
# management but attenders not willing to the same, hence being discharged at
#
# request with following advice.
#
# CONDITION AT DISCHARGE:
#
# Hemodynamically stable
#
# ADVICE ON DISCHARGE:
# TAB. RACTIPER 40MG | 1-0-0 7 BANS
# (BEFORE FOOD)
# TAB. EMESET 4M | 3 DAYS |
#
# 1-0-1 5 DAYS
#
# TAB M STRONG —_}* 1-0-0 14 DAYS
#
# 3 DAYS
#
# wo | bo — Fs
# >
#
# .
# 7 TAB. ENTR¢
#
# TAB. MEFTAL SPAS ITABSOS | 4TABLETS
#
# FOLLOW-UP INSTRUCTIONS:
#
# hii -| 3 DAYS
#
# Urine culture and sensitivity sent- report awaited.
# Review immediately in case of fever, loose stools, vomiting, fatigue.
# Review on 09.05.2026. CBC
# ER OBSERVATION CHART(1)
#
# Triage Categus y
# MARN:_ Red Yellow — Green
#
# eR (oe op [] | MLN
#
# Diagnosis: Time of arrival
#
# De B ER Doctor: Time of response
#
# Time of response
#
# VITAL PARAMETERS
#
# ill ed cc
# Ss =)
# bs |
# ehh | | fm ee | |
# fied cca A = ep
# Or (mur)
#
# sh a (7
# ishs
#
# Procedures Pain scale
# a
#
# (S)
# (S)
#
# wen
# arnt Bar rate a mini om
#
# Ae gee hae Pere, pairs
# i | I | i a F | a a
#
# Note: If score is> 2 please speak to consultant
#
# other orders:
# End Time
#
# uw
# z
# pat
# rf
# r
# o.
# 2.
# & =.
# or
# +8
# g
# = &
# ae
#
# Medication Administration
#
# Name of drug/ strength pects pen Verified i Administered by Time
# =
#
# Fate nt advised admission to ward/Icu Qply
#
# Patient advised discharge / referred to outside hospital
# Refusal of Treatment
# INVESTIGATION CHECKLIST
#
# Stati Name
#
# IIIT THTTHHI)
# Li
# eo
# s)| 3
# os
# Sl
#
# PRUETT
# ABET LET TT ERTL RELL
#
# ARO
#
# Investigation
#
# Time
#
# Date

# %%
response = model.generate_content(
    "Say hello"
)

print(response.text)
# Out:
# Hello!

# %%
# reading pdf and finding missing info
def discharge_agent(text):

    prompt = f"""
You are an AI Discharge Summary Agent.

TASKS:

1. Extract Patient Demographics
2. Extract Admission Date
3. Extract Discharge Date
4. Extract Principal Diagnosis
5. Extract Secondary Diagnoses
6. Extract Procedures
7. Extract Allergies
8. Extract Discharge Medications
9. Detect Medication Changes
10. Detect Missing Information
11. Detect Pending Results
12. Detect Conflicts
13. Generate Clinician Review Flags
14. Generate Discharge Summary
15. Generate Agent Trace

IMPORTANT RULES:

- Never invent facts.
- Never guess.
- If information is missing write:

MISSING - CLINICIAN REVIEW REQUIRED

- If a result is pending write:

PENDING

PATIENT RECORD:

{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
report = discharge_agent(all_text)

print(report)
# Out:
# **1. Patient Demographics**
# *   Name: MISSING - CLINICIAN REVIEW REQUIRED
# *   Age: MISSING - CLINICIAN REVIEW REQUIRED
# *   Gender: Female (implied by "she")
# *   Date of Birth: MISSING - CLINICIAN REVIEW REQUIRED
# *   Medical Record Number: MISSING - CLINICIAN REVIEW REQUIRED
#
# **2. Admission Date**
# *   Admission Date: MISSING - CLINICIAN REVIEW REQUIRED
#
# **3. Discharge Date**
# *   Discharge Date: MISSING - CLINICIAN REVIEW REQUIRED
#
# **4. Principal Diagnosis**
# *   Acute Gastroenteritis with Dehydration
#
# **5. Secondary Diagnoses**
# *   Urinary Tract Infection (suspected, based on urine routine and culture sent)
# *   Thyroid Disorder (Past History, on treatment)
# *   Grade-I Fatty Liver Changes
# *   Mildly Edematous Ascending Colon (possible colitis)
#
# **6. Procedures**
# *   USG Abdomen and Pelvis
#
# **7. Allergies**
# *   Allergies: MISSING - CLINICIAN REVIEW REQUIRED
#
# **8. Discharge Medications**
# *   TAB. RACTIPER 40MG: 1-0-0 (before food) for 7 DAYS
# *   TAB. EMESET 4MG: 1-0-1 for 5 DAYS
# *   TAB. M STRONG: 1-0-0 for 14 DAYS
# *   TAB. ENTROSTAT: For 3 DAYS
# *   TAB. MEFTAL SPAS: 4 TABLETS for 3 DAYS
#
# **9. Detect Medication Changes**
# *   **IV PPI's** (during admission) changed to **TAB. RACTIPER 40MG** (oral PPI) on discharge.
# *   **IV antiemetics** (during admission) changed to **TAB. EMESET 4MG** (oral antiemetic) on discharge.
# *   **IV antibiotics** (during admission) were administered, but **no oral antibiotic** is prescribed on discharge despite the diagnosis of Urinary Tract Infection and positive urine routine findings (pus cells, bacteria, ketones).
# *   **Thyroid disorder medication:** Status of ongoing thyroid medication is not explicitly stated in discharge advice.
#
# **10. Detect Missing Information**
# *   Patient's full name, age, date of birth, and medical record number.
# *   Specific admission date.
# *   Specific discharge date.
# *   Known allergies.
# *   Specific daily dosage for TAB. ENTROSTAT.
# *   Specific daily dosage for TAB. MEFTAL SPAS.
# *   Specific drug name/composition for TAB. M STRONG.
# *   Specific IV antibiotics administered during admission.
# *   Clear instructions regarding continuation or adjustment of existing thyroid disorder medication.
#
# **11. Detect Pending Results**
# *   Urine culture and sensitivity report: PENDING
#
# **12. Detect Conflicts**
# *   **Discharge Against Medical Advice:** Patient was advised to stay for further management, but attenders requested discharge.
# *   **Unaddressed Infection:** No oral antibiotic prescribed for suspected Urinary Tract Infection (based on urine routine and culture sent), despite IV antibiotics being administered during admission.
#
# **13. Generate Clinician Review Flags**
# *   **MISSING PATIENT DEMOGRAPHICS:** Name, Age, Date of Birth, MRN.
# *   **MISSING DATES:** Admission Date, Discharge Date.
# *   **MISSING ALLERGIES.**
# *   **DISCHARGE AGAINST MEDICAL ADVICE.**
# *   **PENDING CRITICAL RESULT:** Urine culture and sensitivity. Clinician to review and follow-up.
# *   **MEDICATION DOSAGE AMBIGUITY:** Daily dosage missing for TAB. ENTROSTAT and TAB. MEFTAL SPAS.
# *   **MEDICATION IDENTITY AMBIGUITY:** Specific drug name/composition needed for TAB. M STRONG.
# *   **POTENTIAL TREATMENT GAP:** No oral antibiotic prescribed for suspected UTI despite positive urine findings and IV antibiotics given during hospitalization. Clinician to review antibiotic plan.
# *   **CLARIFICATION ON CHRONIC MEDICATION:** Status of thyroid medication requires clarification.
#
# **14. Generate Discharge Summary**
#
# **DISCHARGE SUMMARY**
#
# **Patient Demographics:**
# *   Name: MISSING - CLINICIAN REVIEW REQUIRED
# *   Age: MISSING - CLINICIAN REVIEW REQUIRED
# *   Gender: Female
# *   Date of Birth: MISSING - CLINICIAN REVIEW REQUIRED
# *   Medical Record Number: MISSING - CLINICIAN REVIEW REQUIRED
#
# **Admission Date:** MISSING - CLINICIAN REVIEW REQUIRED
# **Discharge Date:** MISSING - CLINICIAN REVIEW REQUIRED
#
# **Principal Diagnosis:**
# *   Acute Gastroenteritis with Dehydration
#
# **Secondary Diagnoses:**
# *   Urinary Tract Infection (suspected)
# *   Thyroid Disorder (Past History, on treatment)
# *   Grade-I Fatty Liver Changes
# *   Mildly Edematous Ascending Colon (possible colitis)
#
# **History of Present Illness:**
# Patient presented with a 3-day history of multiple episodes of loose stools, 2-3 episodes of vomiting, and fatigue, along with fever since yesterday. She had received initial treatment at a local clinic.
#
# **Past Medical History:**
# Known case of Thyroid Disorder, currently on treatment.
#
# **Course in Hospital:**
# Upon admission, initial investigations revealed normal CBC, elevated serum creatinine (1.65 me/dl) which subsequently normalized (1.17 me/dl), and low serum sodium (125.00 mmol/L). Urine routine showed ketone bodies (+), 10-12/hpf pus cells, 13-20/hpf epithelial cells, and presence of bacteria; urine culture and sensitivity was sent and is PENDING. Stool routine showed 2-3/hpf red blood cells and plenty/hpf pus cells. USG abdomen and pelvis identified Grade-I fatty liver changes and a mildly edematous ascending colon up to the hepatic flexure, suggestive of colitis. TSH and Free T4 levels were normal.
# Treatment included IV fluids, IV antibiotics, IV PPI's, IV antiemetics, and other supportive measures.
# Patient was advised to stay for further management, but attenders requested discharge against medical advice.
#
# **Condition at Discharge:**
# Hemodynamically stable.
#
# **Discharge Medications:**
# 1.  TAB. RACTIPER 40MG: 1-0-0 (before food) for 7 DAYS
# 2.  TAB. EMESET 4MG: 1-0-1 for 5 DAYS
# 3.  TAB. M STRONG: 1-0-0 for 14 DAYS
# 4.  TAB. ENTROSTAT: For 3 DAYS (Daily dosage: MISSING - CLINICIAN REVIEW REQUIRED)
# 5.  TAB. MEFTAL SPAS: 4 TABLETS for 3 DAYS (Daily dosage: MISSING - CLINICIAN REVIEW REQUIRED)
#
# **Follow-up Instructions:**
# *   Urine culture and sensitivity report: PENDING. Clinician to review and provide further instructions.
# *   Review immediately in case of fever, loose stools, vomiting, or fatigue.
# *   Review on 09.05.2026 for CBC.
#
# **15. Generate Agent Trace**
# 1.  **Extracted Patient Demographics:** Scanned for Name, Age, Gender, DOB, MRN. Identified Gender as Female (implied) and marked all other demographics as MISSING.
# 2.  **Extracted Admission Date:** Searched for explicit admission date. Marked as MISSING.
# 3.  **Extracted Discharge Date:** Searched for explicit discharge date. Marked as MISSING.
# 4.  **Extracted Principal Diagnosis:** Identified "Acute Gastroenteritis with Dehydration" as the primary reason for acute presentation and management.
# 5.  **Extracted Secondary Diagnoses:** Identified "Urinary Tract Infection" (suspected), "Thyroid Disorder" (past history), "Grade-I Fatty Liver Changes", and "Mildly Edematous Ascending Colon (possible colitis)" from the DIANGOSIS, PAST HISTORY, and COURSE IN THE HOSPITAL sections.
# 6.  **Extracted Procedures:** Identified "USG abdomen and pelvis" as a diagnostic procedure performed.
# 7.  **Extracted Allergies:** Scanned the entire record for any mention of allergies. Marked as MISSING.
# 8.  **Extracted Discharge Medications:** Listed all medications and their instructions directly from the "ADVICE ON DISCHARGE" section. Noted the lack of specific daily dosages for ENTROSTAT and MEFTAL SPAS, and the generic nature of M STRONG.
# 9.  **Detected Medication Changes:**
#     *   Compared IV medications during stay (IV PPIs, IV antiemetics, IV antibiotics) with discharge medications.
#     *   Noted conversion from IV PPIs to oral RACTIPER.
#     *   Noted conversion from IV antiemetics to oral EMESET.
#     *   Identified the critical absence of an oral antibiotic despite IV use during stay and UTI findings.
#     *   Noted lack of explicit instruction for ongoing thyroid medication.
# 10. **Detected Missing Information:** Consolidated all identified missing data points from tasks 1, 2, 3, 7, and 8, along with critical clinical information like specific medication details and chronic medication status.
# 11. **Detected Pending Results:** Identified "Urine culture and sensitivity sent - report awaited" from the "COURSE IN THE HOSPITAL" and "FOLLOW-UP INSTRUCTIONS" sections.
# 12. **Detected Conflicts:**
#     *   Identified "discharge at request" against medical advice.
#     *   Identified the clinical conflict of discontinuing IV antibiotics and not prescribing an oral antibiotic for a suspected UTI.
# 13. **Generated Clinician Review Flags:** Synthesized findings from missing information, pending results, and conflicts to create a comprehensive list of items requiring clinician attention.
# 14. **Generated Discharge Summary:** Compiled all extracted information into a structured discharge summary format, incorporating missing information and pending results as per the rules.
# 15. **Generated Agent Trace:** Documented the step-by-step process of fulfilling all requested tasks.

# %%
# Clinical Review Report
def review_agent1(text):

    prompt = f"""
You are a Clinical Safety Reviewer.

Review the patient record.

Return:

1. Missing Information

2. Pending Results

3. Medication Concerns

4. Conflicts

5. Clinician Review Required Actions

Never invent facts.

Patient Record:

{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
review_report = review_agent1(all_text)

print(review_report)
# Out:
# As a Clinical Safety Reviewer, here is an analysis of the patient record:
#
# ---
#
# **1. Missing Information:**
#
# *   **Patient Demographics:** Age and gender are not specified.
# *   **Allergies:** Not documented.
# *   **Initial Local Clinic Treatment:** Specific medications and details of initial treatment received at the local clinic are not provided.
# *   **Medication History on Admission:** A complete list of medications the patient was taking at home, especially for the "Thyroid disorder on treatment," is missing. This is crucial for medication reconciliation and preventing medication errors.
# *   **Detailed IV Treatment:** Specific names, dosages, and durations of IV fluids, IV antibiotics, IV PPIs, and IV antiemetics administered during hospitalization are not detailed.
# *   **Discharge Vital Signs:** Beyond "Hemodynamically stable," specific vital signs (PR, BP, RR, SpO2, Temperature) at discharge are not documented.
# *   **Electrolyte/Creatinine on Discharge:** While repeat creatinine improved, there's no mention of repeat electrolytes (specifically sodium) or creatinine immediately prior to discharge to confirm complete resolution of initial abnormalities.
# *   **Full Medication Instructions:** Duration is missing for TAB. EMESET and TAB. ENTR. "Before food" instruction is only given for RACTIPER. Other specific instructions for administration are absent.
# *   **Thyroid Medication:** Despite a history of "Thyroid disorder on treatment" and "TSH and Free T4 done were normal" (implying continued treatment), no specific thyroid medication is listed on discharge. It's unclear if it was held, discontinued, or inadvertently omitted.
# *   **Nutritional/Dietary Advice:** No specific dietary recommendations or advice on oral rehydration solutions are provided, despite diagnoses of gastroenteritis and dehydration.
# *   **ER Observation Chart:** The provided ER Observation Chart is almost entirely blank, indicating a significant lack of documentation regarding initial triage, vital parameters, pain assessment, and other orders in the Emergency Room.
# *   **Weight/Height:** Not documented, which can be relevant for medication dosing (e.g., renal dosing) and assessing dehydration.
#
# ---
#
# **2. Pending Results:**
#
# *   **Urine culture and sensitivity:** This report is explicitly stated as "awaited."
#
# ---
#
# **3. Medication Concerns:**
#
# *   **Unclear Medications:**
#     *   **TAB. M STRONG:** The exact identity, indication, and dosage/duration rationale for "M STRONG" are unclear. This could potentially be an antibiotic (e.g., Metronidazole) given the infection context, but without clarification, its appropriateness for a 14-day course is questionable.
#     *   **TAB. ENTRO:** The exact identity, indication, and dosage/duration rationale for "ENTRO" are unclear. It could be an anti-diarrheal, probiotic, or another antibiotic.
# *   **Lack of Specific Oral Antibiotic for UTI:** The patient was diagnosed with a UTI and received IV antibiotics in the hospital. However, no specific oral antibiotic is clearly prescribed on discharge for the UTI, pending the culture results. This is a significant omission, as empiric oral antibiotics are usually initiated until culture results guide therapy.
# *   **Thyroid Medication Omission:** As noted in Missing Information, the patient's regular thyroid medication for her "Thyroid disorder on treatment" is not listed on discharge. This is a critical safety concern as abrupt discontinuation could lead to hypothyroidism.
# *   **Meftal Spas (Mefenamic Acid/Dicyclomine) Use:**
#     *   **NSAID Component (Mefenamic Acid):** The patient presented with elevated serum creatinine (though now normal) and dehydration. NSAIDs can precipitate acute kidney injury, especially in dehydrated states or with existing renal compromise. Given the history, even a short course should be used cautiously.
#     *   **GI Irritation:** Stool routine showed 2-3/hpf of red blood cells and plenty/hpf of pus cells, suggestive of colitis/GI inflammation. NSAIDs can worsen GI irritation or bleeding.
#     *   **Anticholinergic Component (Dicyclomine):** Antispasmodics can mask symptoms or potentially worsen gut motility in certain types of infective colitis, especially if not well-characterized.
# *   **Incomplete Discharge Medication Instructions:** The duration is not specified for TAB. EMESET and TAB. ENTRO, leading to potential patient confusion and improper medication use.
#
# ---
#
# **4. Conflicts:**
#
# *   **Discharge Against Medical Advice:** "Patient was adviced to stay back for further management but attenders not willing to the same, hence being discharged at request." This indicates a conflict between the clinician's recommendation and the patient/attenders' decision. The documentation implies the risks were discussed but does not detail the specifics of that discussion.
# *   **UTI Diagnosis vs. Medication:** A definite diagnosis of "URINARY TRACT INFECTION" is made, but no clear oral antibiotic is prescribed on discharge. This is a direct conflict between diagnosis and management plan.
# *   **Colitis Findings vs. Medication:** Stool studies showed RBCs and pus cells, and USG suggested colitis, yet no specific antibiotic for enterocolitis is clearly identified in the discharge medications. Furthermore, the use of an NSAID (Meftal Spas) might be contraindicated or risky in this context.
# *   **Elevated Creatinine History vs. NSAID Use:** The patient had an elevated creatinine on admission. While it normalized, prescribing an NSAID (Meftal Spas) raises a concern for potential renal insult, especially if the patient were to become dehydrated again at home.
#
# ---
#
# **5. Clinician Review Required Actions:**
#
# *   **Clarify Unclear Medications:** Immediately clarify the exact identities, intended indications, and rationale for "TAB. M STRONG" and "TAB. ENTRO."
# *   **Prescribe Appropriate Oral Antibiotic for UTI:** Initiate an empiric oral antibiotic for the diagnosed UTI, ensuring it's appropriate pending the urine culture and sensitivity results. Clearly document the name, dosage, and duration.
# *   **Reconcile Thyroid Medication:** Verify if the patient's regular thyroid medication was intentionally stopped or accidentally omitted. If it's to be continued, it must be explicitly added to the discharge medication list with clear instructions.
# *   **Re-evaluate Meftal Spas:** Reassess the appropriateness and necessity of Meftal Spas, particularly the NSAID component, given the history of elevated creatinine, dehydration, and findings of RBCs/pus cells in stool suggestive of colitis. Consider safer alternatives for pain/spasm if required.
# *   **Complete Medication Instructions:** Ensure all discharge medications have complete and clear instructions, including dosage, frequency, specific administration details (e.g., with food), and total duration of treatment.
# *   **Confirm Resolution of Dehydration/Electrolytes:** If not already done, ensure that dehydration and electrolyte imbalances (especially sodium) have fully resolved before discharge, or provide explicit instructions for monitoring and management at home (e.g., oral rehydration solutions).
# *   **Provide Specific Colitis Management:** Given the findings of RBCs and pus cells in stool and possible colitis, provide specific advice for managing colitis symptoms, dietary modifications, and clear instructions on when to seek immediate medical attention.
# *   **Detail Discharge Against Medical Advice Discussion:** Document more thoroughly the specific risks of early discharge against medical advice that were discussed with the patient/attenders and their understanding.
# *   **Complete ER Observation Chart:** Investigate why the ER Observation Chart is largely blank and ensure proper charting practices are followed for future patient encounters.
# *   **Patient Education:** Ensure the patient understands the importance of follow-up for the pending urine culture result and what actions to take based on the result. Explicitly advise on increased fluid intake and potentially oral rehydration solutions for gastroenteritis and dehydration.

# %%
def review_agent(text):

    prompt = f"""
Find:

1. Missing Information
2. Pending Results
3. Clinician Review Flags

Patient Record:
{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
# diagnosis extraction
def diagnosis_agent(text):

    prompt = f"""
Extract only the diagnoses from the patient record.

Return concise bullet points.

Patient Record:
{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
review_report = review_agent(all_text)

# %%
diagnosis = diagnosis_agent(all_text)

print(diagnosis)
# Out:
# Here are the diagnoses from the patient record:
#
# *   Acute Gastroenteritis with Dehydration
# *   Urinary Tract Infection
# *   Thyroid disorder (on treatment)
# *   Grade-I fatty liver changes

# %%
# Medication Reconciliation
def medication_reconciliation(text):

    prompt = f"""
You are a Medication Reconciliation Agent.

Find:

1. Admission Medications

2. Discharge Medications

3. Added Medications

4. Removed Medications

5. Changed Medications

6. Changes without documented reason

Flag anything suspicious.

Patient Record:

{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
med_report = medication_reconciliation(all_text)

print(med_report)
# Out:
# As a Medication Reconciliation Agent, here is an analysis of the patient's record:
#
# ---
#
# **Medication Reconciliation Report**
#
# **Patient Diagnosis:** Acute Gastroenteritis with Dehydration, Urinary Tract Infection
#
# **1. Admission Medications:**
#
# *   **Chronic Home Medications:**
#     *   Medication for **Thyroid disorder** (Specific medication name and dose not documented, but noted as "on treatment").
# *   **Acute Hospital Medications (initiated during stay):**
#     *   IV Fluids
#     *   IV Antibiotics
#     *   IV PPIs
#     *   IV Antiemetics
#     *   Other supportive measures (non-specific)
#
# **2. Discharge Medications:**
#
# *   **TAB. RACTIPER 40MG:** 1 tablet once daily (1-0-0) for 7 days (to be taken before food).
# *   **TAB. EMESET 4M:** 1 tablet twice daily (1-0-1) for 3 days.
# *   **TAB. M STRONG:** 1 tablet once daily (1-0-0) for 14 days.
# *   **TAB. ENTROFLORA:** 1 tablet once daily (1-0-0) for 5 days.
# *   **TAB. MEFTAL SPAS:** 1 tablet as needed (SOS) for pain/spasms, total of 4 tablets.
#
# **3. Added Medications (New prescriptions at discharge not present on chronic admission list):**
#
# *   TAB. RACTIPER 40MG (Likely an oral PPI, replacing IV PPIs given in hospital for gastroenteritis/colitis/gastritis).
# *   TAB. EMESET 4M (Oral antiemetic, replacing IV antiemetics given in hospital for vomiting).
# *   TAB. M STRONG (Likely an oral antibiotic, replacing IV antibiotics given in hospital for UTI/Gastroenteritis).
# *   TAB. ENTROFLORA (Probiotic, for GI health/antibiotic support).
# *   TAB. MEFTAL SPAS (For pain/spasms, related to GI symptoms/colitis).
#
# **4. Removed Medications (Medications present at admission but not continued at discharge):**
#
# *   **Thyroid medication:** The patient was "K/C/O Thyroid disorder on treatment" but no thyroid medication is listed on the discharge advice.
# *   **IV Fluids**
# *   **IV Antibiotics** (switched to oral, if M Strong is an oral antibiotic)
# *   **IV PPIs** (switched to oral Ractiper)
# *   **IV Antiemetics** (switched to oral Emeset)
#
# **5. Changed Medications (Change in dose, frequency, route, or formulation from admission to discharge):**
#
# *   **IV PPIs** changed to oral **TAB. RACTIPER 40MG** (Change in route/formulation from acute hospital treatment).
# *   **IV Antiemetics** changed to oral **TAB. EMESET 4M** (Change in route/formulation from acute hospital treatment).
# *   **IV Antibiotics** changed to oral **TAB. M STRONG** (Change in route/formulation from acute hospital treatment).
#
# *Note: There are no documented changes in dose or frequency for the patient's chronic thyroid medication, as it appears to have been omitted from the discharge plan.*
#
# **6. Changes without documented reason:**
#
# *   **Removal of Thyroid Medication:** The patient's chronic thyroid medication is *not* listed on the discharge advice. While TSH and Free T4 were reported as normal during the hospital stay, this typically indicates the *current dose* is effective, not a reason to discontinue the medication. There is no documented physician order or explanation for stopping this critical chronic medication.
# *   **Specific Oral Antibiotic (M STRONG) prescribed when urine culture and sensitivity are awaited:** While empiric antibiotic treatment is common, the specific choice of "M Strong" for 14 days is made without the final culture results. This is not necessarily *without reason* (empiric treatment for suspected UTI/Gastroenteritis), but highlights the importance of the awaited culture report and follow-up.
#
# **7. Suspicious Flags:**
#
# *   **CRITICAL: Missing Chronic Thyroid Medication at Discharge.** The patient has a documented history of "Thyroid disorder on treatment." The complete omission of this medication from the discharge plan is a significant medication error and poses a high risk for the patient's health. This needs **immediate clarification and correction** with the prescribing physician. Normal TSH/Free T4 during hospitalization typically means the *existing* dose is therapeutic, not that the medication should be stopped.
# *   **Ambiguous Antibiotic Name (M STRONG):** "M Strong" is not a universally recognized antibiotic name. This lack of clarity can lead to confusion, potential dispensing errors, and makes it difficult to verify appropriateness or potential interactions. It would be safer to use the generic name (e.g., Metronidazole, Ciprofloxacin).
# *   **Discharge Against Medical Advice:** The patient was discharged "at request" despite being "adviced to stay back for further management." This poses a higher risk for complications, especially with an awaited urine culture and sensitivity report, and incomplete treatment of complex conditions (colitis, electrolyte imbalance). The discharge medication plan needs to be robust for home care under these circumstances.
# *   **Incomplete Admission Medication Information:** The specific name and dose of the thyroid medication "on treatment" were not documented at admission. This gap makes comprehensive reconciliation more challenging and contributes to the risk of unintentional discontinuation.

# %%
def medication_agent(text):

    prompt = f"""
Extract discharge medications and medication changes.

Patient Record:
{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
med_report = medication_agent(all_text)

# %%
#Evidence Extraction
def evidence_agent(text):

    prompt = f"""
For every diagnosis provide:

Diagnosis

Evidence

Source Information

Patient Record:

{text}
"""

    response = model.generate_content(prompt)

    return response.text

# %%
evidence = evidence_agent(all_text)

print(evidence)
# Out:
# Here's the breakdown for each diagnosis:
#
# ---
#
# **Diagnosis:** ACUTE GASTROENTERITIS WITH DEHYDRATION
#
# **Evidence:**
# *   **Symptoms:**
#     *   Multiple episodes of loose stools (HISTORY)
#     *   2-3 episodes of vomiting (HISTORY)
#     *   Fatigue since 3 days (HISTORY)
#     *   Fever since yesterday (HISTORY - *can be associated with gastroenteritis*)
# *   **Physical Examination:** (No specific findings directly listed for gastroenteritis, but general vital signs are stable after initial presentation)
# *   **Investigations:**
#     *   Elevated Serum creatinine (1.65mg/dl) (INVESTIGATIONS/COURSE IN THE HOSPITAL - *suggestive of pre-renal azotemia due to dehydration*)
#     *   Low serum sodium (125.00mmol/L) (INVESTIGATIONS/COURSE IN THE HOSPITAL - *can be associated with severe gastroenteritis and fluid imbalance*)
#     *   Urine routine done showed ketone bodies(+) (INVESTIGATIONS/COURSE IN THE HOSPITAL - *can indicate dehydration and reduced oral intake*)
#     *   USG abdomen and pelvis showed mildly edematous part of ascending colon upto the hepatic flexure- could represent colitis (INVESTIGATIONS/COURSE IN THE HOSPITAL - *consistent with inflammation in gastroenteritis*)
#     *   Stool routine done showed 2-3/hpf of red blood cells, plenty/hpf of pus cells (INVESTIGATIONS/COURSE IN THE HOSPITAL - *indicates inflammation/infection in the GI tract*)
# *   **Treatment & Response:**
#     *   Treated with IV fluids (COURSE IN THE HOSPITAL - *direct treatment for dehydration*)
#     *   Treated with IV antiemetics (COURSE IN THE HOSPITAL - *addresses vomiting*)
#     *   Repeat Serum Creatinine (1.17mg/dl) done was normal (COURSE IN THE HOSPITAL - *improvement suggests initial elevation was likely due to dehydration*)
#     *   Discharged with TAB. EMESET (antiemetic) and TAB. ENTRIC (likely an antidiarrheal or GI antibiotic) (ADVICE ON DISCHARGE)
#
# **Source Information:**
# *   HISTORY
# *   INVESTIGATIONS
# *   COURSE IN THE HOSPITAL
# *   ADVICE ON DISCHARGE
#
# ---
#
# **Diagnosis:** URINARY TRACT INFECTION
#
# **Evidence:**
# *   **Symptoms:**
#     *   Fever since yesterday (HISTORY - *common symptom of infection*)
# *   **Physical Examination:** (No specific findings directly listed for UTI)
# *   **Investigations:**
#     *   Urine routine done showed 10-12/hpf of pus cells (INVESTIGATIONS/COURSE IN THE HOSPITAL - *indicates pyuria, a hallmark of UTI*)
#     *   Urine routine done showed presence of bacteria (INVESTIGATIONS/COURSE IN THE HOSPITAL - *direct evidence of bacteriuria*)
#     *   Urine culture and sensitivity sent (INVESTIGATIONS/COURSE IN THE HOSPITAL - *confirmatory test for UTI*)
# *   **Treatment & Response:**
#     *   Treated with IV antibiotics (COURSE IN THE HOSPITAL - *direct treatment for bacterial infection*)
#     *   Discharged with TAB M STRONG (likely an antibiotic) (ADVICE ON DISCHARGE)
#
# **Source Information:**
# *   HISTORY
# *   INVESTIGATIONS
# *   COURSE IN THE HOSPITAL
# *   ADVICE ON DISCHARGE

# %%
trace = []

trace.append({
    "step": 1,
    "reasoning": "Analyze patient record",
    "action": "Discharge Agent",
    "result": "Patient record processed"
})

trace.append({
    "step": 2,
    "reasoning": "Extract diagnoses and medications",
    "action": "Information Extraction",
    "result": "Diagnoses, medications and pending results extracted"
})

trace.append({
    "step": 3,
    "reasoning": "Check for missing information",
    "action": "Safety Review",
    "result": "Missing fields and review flags generated"
})

trace.append({
    "step": 4,
    "reasoning": "Generate final summary",
    "action": "Summary Generator",
    "result": "Discharge summary generated"
})

# %%
for item in trace:
    print("\n----------------")
    print(f"STEP: {item['step']}")
    print(f"REASONING: {item['reasoning']}")
    print(f"ACTION: {item['action']}")
    print(f"RESULT: {item['result']}")
# Out:
# ----------------
# STEP: 1
# REASONING: Analyze patient record
# ACTION: Discharge Agent
# RESULT: Patient record processed
#
# ----------------
# STEP: 2
# REASONING: Extract diagnoses and medications
# ACTION: Information Extraction
# RESULT: Diagnoses, medications and pending results extracted
#
# ----------------
# STEP: 3
# REASONING: Check for missing information
# ACTION: Safety Review
# RESULT: Missing fields and review flags generated
#
# ----------------
# STEP: 4
# REASONING: Generate final summary
# ACTION: Summary Generator
# RESULT: Discharge summary generated

# %%
trace = [
    {
        "step": 1,
        "reasoning": "Need diagnoses",
        "action": "Diagnosis Agent",
        "result": diagnosis[:300]
    },
    {
        "step": 2,
        "reasoning": "Need medication reconciliation",
        "action": "Medication Agent",
        "result": med_report[:300]
    },
    {
        "step": 3,
        "reasoning": "Need safety review",
        "action": "Review Agent",
        "result": review_report[:300]
    },
    {
        "step": 4,
        "reasoning": "Generate discharge summary",
        "action": "Summary Agent",
        "result": " Final Summary generated successfully"
    }
]

# %%
for step in trace:
    
    print("\n----------------")
    print("STEP:", step["step"])
    print("REASONING:", step["reasoning"])
    print("ACTION:", step["action"])
    print("RESULT:", step["result"])
# Out:
# ----------------
# STEP: 1
# REASONING: Need diagnoses
# ACTION: Diagnosis Agent
# RESULT: Here are the diagnoses from the patient record:
#
# *   Acute Gastroenteritis with Dehydration
# *   Urinary Tract Infection
# *   Thyroid disorder (on treatment)
# *   Grade-I fatty liver changes
#
# ----------------
# STEP: 2
# REASONING: Need medication reconciliation
# ACTION: Medication Agent
# RESULT: Here are the extracted discharge medications and medication changes:
#
# ---
#
# **Discharge Medications:**
#
# *   **TAB. RACTIPER 40MG:** 1-0-0 (once daily) for 7 DAYS (Before Food)
# *   **TAB. EMESET 4MG:** 1-0-1 (twice daily) for 3 DAYS
# *   **TAB. M STRONG:** 1-0-0 (once daily) for 14 DAYS
# *   **TAB. ENTR
#
# ----------------
# STEP: 3
# REASONING: Need safety review
# ACTION: Review Agent
# RESULT: Here's the breakdown of the patient record:
#
# ### 1. Missing Information
#
# *   **ER Observation Chart:**
#     *   Triage Category (Red, Yellow, Green) is not selected.
#     *   Nurse and ER Doctor names are missing.
#     *   Time of arrival and Time of response are missing.
#     *   All vital parameters (
#
# ----------------
# STEP: 4
# REASONING: Generate discharge summary
# ACTION: Summary Agent
# RESULT: Summary generated successfully

# %%
with open("Discharge_Summary.txt","w",encoding="utf-8") as f:
    f.write(report)

with open("Medication_Report.txt","w",encoding="utf-8") as f:
    f.write(med_report)

with open("Review_Report.txt","w",encoding="utf-8") as f:
    f.write(review_report)

print("Files Saved")
# Out:
# Files Saved

# %%
with open("Trace_Log.txt","w",encoding="utf-8") as f:

    for step in trace:

        f.write(f"\nSTEP: {step['step']}\n")
        f.write(f"REASONING: {step['reasoning']}\n")
        f.write(f"ACTION: {step['action']}\n")
        f.write(f"RESULT: {step['result']}\n")
        f.write("\n-------------------\n")

print("Trace Saved")
# Out:
# Trace Saved
